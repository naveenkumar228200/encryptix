# %%
import numpy as np;
import pandas as pd;
import seaborn as sea;

# %%
data = pd.read_csv('/content/advertising.csv');

# %%
print(data.head());
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
print(data.describe());
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
print(data.isnull().sum());
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
sea.relplot(x = 'Sales',y = 'Radio',data = data);

# %%
sea.relplot(x = 'Sales',y = 'TV',data = data);

# %%
sea.relplot(x = 'Sales',y = 'Newspaper',data = data);

# %%
from sklearn.linear_model import LinearRegression;
from sklearn.model_selection import train_test_split;

# %%
train = data.drop(['Sales'], axis = 1);
test = data['Sales'];

# %%
X_train,X_test,Y_train,Y_test = train_test_split(train,test,test_size = 0.3,random_state = 42);

# %%
regr = LinearRegression();

# %%
regr.fit(X_train,Y_train);

# %%
pred = regr.predict(X_test);

# %%
print(regr.score(X_test,Y_test));
# Out:
# 0.9091484341849799
